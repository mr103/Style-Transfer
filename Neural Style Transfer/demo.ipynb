# %%
import os
from utils import *
from visu import *

# %%
style_imgs, content_imgs = demo_images()
display_style_content(content_imgs, ['Forest', 'City'])
display_style_content(style_imgs, ['Action_painting','Northern_Renaissance','Romanticism'])

# %%
output = demo_style_transfer(content_imgs, style_imgs)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /tmp/xdg-cache/torch/checkpoints/vgg19-dcbb9e9d.pth
# 100%|██████████| 548M/548M [00:06<00:00, 88.7MB/s]
# 1/6. Content: Forest, Style: Action_painting transfer start!
#
# Building the style transfer model...
# Optimizing...
#
# run 20/200, Style Loss: 1202.392334, Content Loss: 27.149111
# run 40/200, Style Loss: 637.454773, Content Loss: 29.515732
# run 60/200, Style Loss: 468.088837, Content Loss: 32.378357
# run 80/200, Style Loss: 344.103058, Content Loss: 34.300060
# run 100/200, Style Loss: 277.335815, Content Loss: 36.271774
# run 120/200, Style Loss: 238.386307, Content Loss: 37.453335
# run 140/200, Style Loss: 210.172699, Content Loss: 38.273449
# run 160/200, Style Loss: 188.806503, Content Loss: 39.032692
# run 180/200, Style Loss: 171.519272, Content Loss: 39.547600
# run 200/200, Style Loss: 157.354019, Content Loss: 40.055138
# run 220/200, Style Loss: 144.600464, Content Loss: 40.444752
# ...

# %%
display_demo_result(output, content_imgs)
